# %% [markdown]
# **目标**：抓取和讯网开放式基金排行榜（QDII）首页(网址：https://jingzhifunds.hexun.com/fund4th/shouyi.aspx### ,需要手动点击【QDII】按钮】)的内容，并将结果保存到本地csv文件。
# ![image.png](attachment:image.png)
#
# ------------------------------

# %% [markdown]
# **导入相应的库**

# %%
import requests
import json
import csv

# %% [markdown]
# **通过开发者工具找出数据对应的网址(json格式)，并将网址保存为变量`url`**

# %% [markdown]
# **通过requests库抓取数据，并通过数据处理，将结果保存为一个名为`fund_list`的列表（内含多个字典，每个字典代表一个基金）**

# %% [markdown]
# **将`fund_list`的内容保存为csv文件，并命名为`fund_qdii.csv`**
