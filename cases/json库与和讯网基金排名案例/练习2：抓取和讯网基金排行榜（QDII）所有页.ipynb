# %% [markdown]
# **目标**：抓取和讯网开放式基金排行榜（QDII）所有页(网址：https://jingzhifunds.hexun.com/fund4th/shouyi.aspx### ,需要手动点击【QDII】按钮】)的内容，并将结果保存到本地csv文件。
#
# ![image.png](attachment:image.png)
# ------------------------------

# %%
# 导入相关的库
import requests
import json
import csv

# %% [markdown]
# # 构造url_list

# %% [markdown]
# **构造一个`url_list`，包含所有和讯网基金排行榜（QDII）的页面url**

# %%
# url_list
# Out:
# ['https://jingzhifunds.hexun.com/jz/JsonData/KaifangPaim.aspx?callback=callback&subtype=7&fundcompany=--%E5%85%A8%E9%83%A8%E5%9F%BA%E9%87%91%E7%AE%A1%E7%90%86%E5%85%AC%E5%8F%B8--&pagesize=20&curpage=1&sortName=m3&sortType=down&fundisbuy=0',
#  'https://jingzhifunds.hexun.com/jz/JsonData/KaifangPaim.aspx?callback=callback&subtype=7&fundcompany=--%E5%85%A8%E9%83%A8%E5%9F%BA%E9%87%91%E7%AE%A1%E7%90%86%E5%85%AC%E5%8F%B8--&pagesize=20&curpage=2&sortName=m3&sortType=down&fundisbuy=0',
#  'https://jingzhifunds.hexun.com/jz/JsonData/KaifangPaim.aspx?callback=callback&subtype=7&fundcompany=--%E5%85%A8%E9%83%A8%E5%9F%BA%E9%87%91%E7%AE%A1%E7%90%86%E5%85%AC%E5%8F%B8--&pagesize=20&curpage=3&sortName=m3&sortType=down&fundisbuy=0',
#  'https://jingzhifunds.hexun.com/jz/JsonData/KaifangPaim.aspx?callback=callback&subtype=7&fundcompany=--%E5%85%A8%E9%83%A8%E5%9F%BA%E9%87%91%E7%AE%A1%E7%90%86%E5%85%AC%E5%8F%B8--&pagesize=20&curpage=4&sortName=m3&sortType=down&fundisbuy=0',
# ...

# %% [markdown]
# # 函数：请求和提取数据
# **定义一个名为get_and_extract_data(url)的函数，该函数接收一个url参数，并返回一个该页包含所有基金排行榜信息的列表`fund_list`**

# %%
# get_and_extract_data(url_template.format(num=1))
# Out:
# [{'num': '1',
#   'fundCode': '160923',
#   'fundName': '大成海外中国机会混合',
#   'fundLink': 'https://jingzhifunds.hexun.com/160923.shtml',
#   'trendLink': 'https://jingzhifunds.hexun.com/database/jzzs.aspx?fundcode=160923',
#   'baLink': 'https://jijinba.hexun.com/160923,jijinba.html',
#   'netValue': '1.6200',
#   'netDate': '02-09',
#   'm1': '6.72%',
#   'm3': '15.22%',
#   'm6': '21.71%',
#   'y1': '34.11%',
#   'y2': '48.90%',
#   'y3': '43.75%',
#   'thisyear': '8.51%',
#   'setup': '62.01%',
#   'discount': '4折',
#   'ratefee': '0.60%',
#   'buy': '3',
#   'buyLink': 'https://emall.licaike.com/fund/purchase/FirstLoad.action?fundCode=160923&knownChannel=hexun_jjjz_goumai',
#   'dtLink': ''},
#  {'num': '2',
#   'fundCode': '161714',
#   'fundName': '招商标普金砖四国',
#   'fundLink': 'https://jingzhifunds.hexun.com/161714.shtml',
#   'trendLink': 'https://jingzhifunds.hexun.com/database/jzzs.aspx?fundcode=161714',
#   'baLink': 'https://jijinba.hexun.com/161714,jijinba.html',
# ...

# %% [markdown]
# # 循环url_list，并将结果写入csv文件

# %%
# Out:
# 正在抓取:https://jingzhifunds.hexun.com/jz/JsonData/KaifangPaim.aspx?callback=callback&subtype=1&fundcompany=--%E5%85%A8%E9%83%A8%E5%9F%BA%E9%87%91%E7%AE%A1%E7%90%86%E5%85%AC%E5%8F%B8--&pagesize=20&curpage=1&sortName=m3&sortType=down&fundisbuy=0
# 正在抓取:https://jingzhifunds.hexun.com/jz/JsonData/KaifangPaim.aspx?callback=callback&subtype=1&fundcompany=--%E5%85%A8%E9%83%A8%E5%9F%BA%E9%87%91%E7%AE%A1%E7%90%86%E5%85%AC%E5%8F%B8--&pagesize=20&curpage=2&sortName=m3&sortType=down&fundisbuy=0
# 正在抓取:https://jingzhifunds.hexun.com/jz/JsonData/KaifangPaim.aspx?callback=callback&subtype=1&fundcompany=--%E5%85%A8%E9%83%A8%E5%9F%BA%E9%87%91%E7%AE%A1%E7%90%86%E5%85%AC%E5%8F%B8--&pagesize=20&curpage=3&sortName=m3&sortType=down&fundisbuy=0
# 正在抓取:https://jingzhifunds.hexun.com/jz/JsonData/KaifangPaim.aspx?callback=callback&subtype=1&fundcompany=--%E5%85%A8%E9%83%A8%E5%9F%BA%E9%87%91%E7%AE%A1%E7%90%86%E5%85%AC%E5%8F%B8--&pagesize=20&curpage=4&sortName=m3&sortType=down&fundisbuy=0
# ...
