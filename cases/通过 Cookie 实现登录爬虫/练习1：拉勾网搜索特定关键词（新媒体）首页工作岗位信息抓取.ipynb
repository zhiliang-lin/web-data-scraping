# %% [markdown]
# ------------------------------
# # 任务：
#
# 在拉勾网搜索关键词“新媒体”，抓取首页的工作岗位信息。
#
# ------------------------------

# %%
template_url = 'https://www.lagou.com/wn/zhaopin?fromSearch=true&kd={keyword}&city={city}'

url = template_url.format(keyword='新媒体', city='广州')

url
# Out:
# 'https://www.lagou.com/wn/zhaopin?fromSearch=true&kd=新媒体&city=广州'
