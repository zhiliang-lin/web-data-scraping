# %% [markdown]
# ------------------------------
# # 任务：
#
# 抓取电影《破·地狱》最新豆瓣短评相关数据，包括用户名、用户评分、用户短评、用户主页链接等。
# - url:
# https://movie.douban.com/subject/36712987/comments?sort=time&status=P
#
# ------------------------------

# %% [markdown]
# # 第一部分：利用Selenium获取cookie信息（如果使用浏览器开发者工具的方法这部分可以跳过）

# %% [markdown]
# # 第二部分：利用cookie信息登录豆瓣

# %% [markdown]
# ------------------------------

# %% [markdown]
# ------------------------------

# %% [markdown]
# # 第三部分：提取数据（测试）

# %% [markdown]
# - **打印短评文本**

# %% [markdown]
# - **打印id名**

# %% [markdown]
# - **打印用户id链接**

# %% [markdown]
# - **打印用户评分**
