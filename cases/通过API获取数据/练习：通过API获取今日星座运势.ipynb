# %% [markdown]
# ------------------------------
# # 任务：通过聚合数据API获取自己的星座的今日运势
# - 要求：通过图示方法复制出请求代码，修改apiKey 和 星座（改成自己的星座）
#  - apiKey用这个（代码请只运行一次即可，因为API请求次数每天有限额的）: d4e6699d5e1daa992d96eb686b7ba788
#
# - url: https://www.juhe.cn/docs/api/id/58
#
# ![image-2.png](attachment:image-2.png)
#
# ------------------------------

# %%
# !pip install requests
