# %% [markdown]
# # **通过 API 获取数据**
#
# API（Application Programming Interface，应用程序编程接口）是一组定义好的规则和协议，允许不同的软件应用程序进行交互和通信。它充当了应用程序与服务或其他应用程序之间的“桥梁”。许多网站和在线服务提供 API，允许开发者以编程方式获取结构化的数据，而无需解析复杂的 HTML 页面。
#
#
# ---
#
# ## **1. 什么是 API？**
# API 是一组定义好的规则，允许不同的软件应用之间进行通信。通过 API 获取数据的优点包括：
# - 数据结构化，易于处理（通常是 JSON 或 XML 格式）。
# - 更高效，避免直接解析网页 HTML。
# - 提供更多功能和信息。
#
# ---
#
# ## **2. API 获取数据的基本流程**
# 1. **注册与获取 API Key**
#    大多数 API 服务要求开发者注册账号，并申请唯一的 API Key，用于验证身份。
#
# 2. **阅读 API 文档**
#    API 提供者会发布文档，详细说明支持的功能、接口地址、参数要求和返回格式。
#
# 3. **构建请求**
#    按照 API 文档的要求，构造请求 URL，包含必要的参数和身份验证信息。
#
# 4. **发送请求并获取响应**
#    使用 HTTP 方法（如 GET、POST）发送请求，并解析返回的数据。
#
# 5. **处理返回的数据**
#    API 通常返回 JSON 格式数据，可以直接解析为 Python 字典进行处理。
#
# ---
#
# ## **3. 核心 Python 库**
# - **`requests`**: 用于发送 HTTP 请求。
# - **`json`**: 用于解析 JSON 数据。
# ------------------------------
#
# ## **4. 核心 API 请求方法**
# - **GET 请求**: 获取资源（如示例中的新闻数据）。
# - **POST 请求**: 提交数据到服务器（如提交表单数据）。
#
# ### **示例：GET 请求**
# ```python
# response = requests.get(url, params={"key": "your_api_key"})
# ```
#
# ### **示例：POST 请求**
# ```python
# data = {"key": "your_api_key", "type": "top"}
# response = requests.post(url, data=data)
# ```
#
# ---
#
# ## **5. 注意事项**
# 1. **API Key 管理**: 切勿在公开的代码中暴露 API Key，可通过环境变量或配置文件存储。
# 2. **调用频率限制**: 大多数 API 对请求频率有严格限制，请遵守文档要求。
# 3. **错误处理**: 检查返回的状态码和 `error_code`，确保请求成功。
#
# ---

# %% [markdown]
# ------------------------------

# %% [markdown]
# # **示例**

# %% [markdown]
# ------------------------------

# %% [markdown]
# ## 示例 1: 通过 [高德地图 API](https://lbs.amap.com/) 获取地理位置信息

# %%
import requests

# API 基础 URL 和参数
api_url = "https://restapi.amap.com/v3/geocode/geo"
params = {
    "key": "a42fd9be52381dfbcc51d70762e38299",  # 在高德地图官网申请的API密钥
    "address": "北京天安门"         # 查询的地址
}

# 发送请求
response = requests.get(api_url, params=params)

# 检查状态码并解析数据
if response.status_code == 200:
    data = response.json()
    if data["status"] == "1":
        geocode = data["geocodes"][0]
        location = geocode["location"]
        print(f"地址: {geocode['formatted_address']}")
        print(f"经纬度: {location}")
    else:
        print("查询失败:", data.get("info", "未知错误"))
else:
    print(f"请求失败，状态码: {response.status_code}")
# Out:
# 地址: 北京市东城区天安门
# 经纬度: 116.397455,39.909187

# %% [markdown]
# ## 示例 2: 通过 [聚合数据 API](https://www.juhe.cn/) 获取新闻头条

# %%
import requests
import json

# API 地址
url = 'http://v.juhe.cn/toutiao/index'

# 请求参数
params = {
    "type": "top",  # 新闻类型
    "key": "c130121723c33705367b5b9b320f4019",  # 您申请的API密钥
}

try:
    # 发起GET请求
    response = requests.get(url, params=params)
    
    # 检查响应状态码
    if response.status_code == 200:
        content = response.json()  # 直接解析JSON响应
        error_code = content.get('error_code')
        
        if error_code == 0:
            data = content['result']['data']
            for i in data:
                # 更多字段可参考接口文档
                print(f"新闻标题：{i['title']}\n新闻时间：{i['date']}\n新闻链接：{i['url']}\n")
        else:
            print(f"请求失败: {content.get('error_code')} {content.get('reason')}")
    else:
        print(f"请求失败，HTTP状态码: {response.status_code}")
except requests.RequestException as e:
    print(f"网络请求异常: {e}")
except Exception as e:
    print(f"解析结果异常: {e}")
# Out:
# 新闻标题：世界上的朱鹮都是亲戚？跨省谈个恋爱吧！
# 新闻时间：2024-12-05 22:57:00
# 新闻链接：https://mini.eastday.com/mobile/241205225730131642924.html
#
# 新闻标题：朱雀系列火箭将参与中国空间站送货
# 新闻时间：2024-12-05 22:57:00
# 新闻链接：https://mini.eastday.com/mobile/241205225724248387718.html
#
# 新闻标题：明年1月1日起施行！《贵州省刚性支出困难家庭认定办法》印发，附政策解读
# 新闻时间：2024-12-05 22:47:00
# 新闻链接：https://mini.eastday.com/mobile/241205224715294789482.html
#
# 新闻标题：凡人微光 温暖山城｜粗心乘客接连丢手机 幸好遇到好心公交驾驶员
# 新闻时间：2024-12-05 22:44:00
# 新闻链接：https://mini.eastday.com/mobile/241205224433623456631.html
#
# 新闻标题：2024东莞全球招商大会签约总金额达2565亿元
# 新闻时间：2024-12-05 22:37:00
# 新闻链接：https://mini.eastday.com/mobile/241205223726298930816.html
#
# 新闻标题：合肥一对老夫妻做公益几十年 曾多次救人性命，耄耋之年仍在为爱奔走
# 新闻时间：2024-12-05 22:34:00
# 新闻链接：https://mini.eastday.com/mobile/241205223429189109213.html
#
# 新闻标题：拒绝酒驾！定安交警曝光三起涉及醉驾典型案例
# 新闻时间：2024-12-05 22:32:00
# 新闻链接：https://mini.eastday.com/mobile/241205223201058333752.html
#
# 新闻标题：【观点摘登】杨龙飞 孙昳恒：丰富数字叙事表达
# 新闻时间：2024-12-05 22:16:00
# 新闻链接：https://mini.eastday.com/mobile/241205221642797334917.html
#
# 新闻标题：贵州网络纪录片《我们的赛场》获中宣部“五个一工程”奖
# 新闻时间：2024-12-05 22:16:00
# 新闻链接：https://mini.eastday.com/mobile/241205221640154771076.html
#
# 新闻标题：中国财长撰文：加快落实一揽子隐性债务化解政策
# 新闻时间：2024-12-05 22:07:00
# 新闻链接：https://mini.eastday.com/mobile/241205220721741157777.html
#
# 新闻标题：中国科研团队提出全新燃料电池数字化设计方法
# 新闻时间：2024-12-05 22:07:00
# 新闻链接：https://mini.eastday.com/mobile/241205220718221854599.html
#
# 新闻标题：台湾11月CPI同比增长2.08％ 菜价、房租涨幅大
# 新闻时间：2024-12-05 22:07:00
# 新闻链接：https://mini.eastday.com/mobile/241205220717497565169.html
#
# 新闻标题：研究机构预测，“十五五”中国机器人产业规模达4000亿元左右
# 新闻时间：2024-12-05 22:07:00
# 新闻链接：https://mini.eastday.com/mobile/241205220716682962520.html
#
# 新闻标题：白皮书：晚期三阴性乳腺癌患者对疾病服务需求多元化
# 新闻时间：2024-12-05 22:07:00
# 新闻链接：https://mini.eastday.com/mobile/241205220715323461728.html
#
# 新闻标题：礼来替尔泊肽实现平均减重20.2% 头对头研究显示优于司美格鲁肽的13.7%
# 新闻时间：2024-12-05 22:07:00
# 新闻链接：https://mini.eastday.com/mobile/241205220714919202440.html
#
# 新闻标题：广东专家创新乙肝治愈新策略 治愈率有望突破30%
# 新闻时间：2024-12-05 22:07:00
# 新闻链接：https://mini.eastday.com/mobile/241205220713728638778.html
#
# 新闻标题：今年华语文学圈已有4位重量级女作家离世：齐邦媛、聂华苓、叶嘉莹和琼瑶
# 新闻时间：2024-12-05 21:56:00
# 新闻链接：https://mini.eastday.com/mobile/241205215625963747269.html
#
# 新闻标题：发布“牛肉检测出兽药超标致癌”不实信息 周至公安依法打击处理
# 新闻时间：2024-12-05 21:50:00
# 新闻链接：https://mini.eastday.com/mobile/241205215050273608674.html
#
# 新闻标题：4支队伍连夜搜救 安全找回走失者
# 新闻时间：2024-12-05 21:46:00
# 新闻链接：https://mini.eastday.com/mobile/241205214612839588718.html
#
# 新闻标题：车被撞 人跑了？ 一场“误会”背后的暖心诚信故事
# 新闻时间：2024-12-05 21:45:00
# 新闻链接：https://mini.eastday.com/mobile/241205214556970525818.html
#
# 新闻标题：上海迪士尼将实施电动轮椅新规：仅限行动不便的人士使用
# 新闻时间：2024-12-05 21:44:00
# 新闻链接：https://mini.eastday.com/mobile/241205214434136511205.html
#
# 新闻标题：北京出台措施发展文化新质生产力 促进文化领域技术创新
# 新闻时间：2024-12-05 21:37:00
# 新闻链接：https://mini.eastday.com/mobile/241205213711143518824.html
#
# 新闻标题：蛇年春节游火热登场：长假带火长线旅游，部分热门航线价格上涨
# 新闻时间：2024-12-05 21:37:00
# 新闻链接：https://mini.eastday.com/mobile/241205213710614187817.html
#
# 新闻标题：10年国债收益率再创新低，年底增量政策受关注
# 新闻时间：2024-12-05 21:37:00
# 新闻链接：https://mini.eastday.com/mobile/241205213710227486341.html
#
# 新闻标题：2024“约会哈尔滨 冰雪暖世界”亚太主流媒体采风活动启动
# 新闻时间：2024-12-05 21:37:00
# 新闻链接：https://mini.eastday.com/mobile/241205213705252445967.html
#
# 新闻标题：儋州市人民医院成功开展琼西地区首例血流导向装置植入手术
# 新闻时间：2024-12-05 21:34:00
# 新闻链接：https://mini.eastday.com/mobile/241205213424196102043.html
#
# 新闻标题：断货、卖空、抢光！杭州姑娘排队2小时花了几十万，这家店为什么这么火？
# 新闻时间：2024-12-05 21:25:00
# 新闻链接：https://mini.eastday.com/mobile/241205212512869989130.html
#
# 新闻标题：第19届国际基因组学大会三亚专场：聚焦基因科技与全球合作 推动生命科学创新发展
# 新闻时间：2024-12-05 21:24:00
# 新闻链接：https://mini.eastday.com/mobile/241205212436601100392.html
#
# 新闻标题：何以中国 | 传承班墨文化，锤炼良匠之师
# 新闻时间：2024-12-05 21:07:00
# 新闻链接：https://mini.eastday.com/mobile/241205210721884719031.html
#
# 新闻标题：智能制造与文化创新的融合之道——卡游入选2024企业家博鳌论坛“新质生产力智能制造典范”
# 新闻时间：2024-12-05 21:06:00
# 新闻链接：https://mini.eastday.com/mobile/241205210659645416994.html

# %% [markdown]
# ## 示例 3: 通过 [网易云音乐 API（非官方）](https://neteasecloudmusicapi.vercel.app/) 获取特定关键词搜索结果

# %%
import requests

# 网易云音乐 API URL
api_url = "https://neteasecloudmusicapi.vercel.app/search?keywords={keywords}"

keywords = "杨千嬅" #自定义关键词

# 发起请求
response = requests.get(api_url.format(keywords=keywords))

# %%
data = response.json()
data
# Out:
# {'result': {'songs': [{'id': 316486,
#     'name': '野孩子',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31350,
#      'name': '千嬅盛放',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1230739200000,
#      'size': 50,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163447787660,
#      'mark': 0},
#     'duration': 224397,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316654,
#     'name': '可惜我是水瓶座',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31362,
#      'name': 'Simply Me',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1170777600000,
#      'size': 48,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163270254510,
#      'alia': ['新曲+精选'],
#      'mark': 0},
#     'duration': 216666,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316510,
#     'name': '稀客',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31350,
#      'name': '千嬅盛放',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1230739200000,
#      'size': 50,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163447787660,
#      'mark': 0},
#     'duration': 194173,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 317251,
#     'name': '少女的祈祷(Live)',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31411,
#      'name': '万紫千红演唱会2002',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1009814400000,
#      'size': 27,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163447778340,
#      'mark': 0},
#     'duration': 223143,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 14199682,
#     'fee': 8,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316429,
#     'name': '处处吻',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31348,
#      'name': '囍爱杨千嬅',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1286208000000,
#      'size': 28,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951163447791550,
#      'alia': ['新歌+精选'],
#      'mark': 0},
#     'duration': 199041,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17180139520},
#    {'id': 316498,
#     'name': '勇',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31350,
#      'name': '千嬅盛放',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1230739200000,
#      'size': 50,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163447787660,
#      'mark': 0},
#     'duration': 221213,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 317245,
#     'name': '再见二丁目(Live)',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31411,
#      'name': '万紫千红演唱会2002',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1009814400000,
#      'size': 27,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163447778340,
#      'mark': 0},
#     'duration': 412479,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 14270568,
#     'fee': 8,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316756,
#     'name': '小城大事',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31370,
#      'name': '电光幻影',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1088092800000,
#      'size': 11,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951164016432340,
#      'mark': 0},
#     'duration': 208506,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 5564634,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316637,
#     'name': '假如让我说下去',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31362,
#      'name': 'Simply Me',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1170777600000,
#      'size': 47,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163270254510,
#      'alia': ['新曲+精选'],
#      'mark': 0},
#     'duration': 207906,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 14249132,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316509,
#     'name': '飞女正传',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31350,
#      'name': '千嬅盛放',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1259856000000,
#      'size': 50,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163447787660,
#      'mark': 0},
#     'duration': 250666,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 14235009,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316733,
#     'name': '烈女',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31368,
#      'name': 'Single',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1114099200000,
#      'size': 12,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951163984014430,
#      'mark': 0},
#     'duration': 236564,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17180139520},
#    {'id': 316678,
#     'name': '寒舍',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31362,
#      'name': 'Simply Me',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1170777600000,
#      'size': 48,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163270254510,
#      'alia': ['新曲+精选'],
#      'mark': 0},
#     'duration': 237186,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 8,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 25877497,
#     'name': '原来过得很快乐',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 2337503,
#      'name': '原来过得很快乐',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1255622400000,
#      'size': 11,
#      'copyrightId': -1,
#      'status': 1,
#      'picId': 4424434790187470,
#      'alia': ['Living Very Happily '],
#      'mark': 0},
#     'duration': 238933,
#     'copyrightId': 1416004,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 2004315157,
#     'name': '还有事情可庆祝',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 156010673,
#      'name': '还有事情可庆祝',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1671465600000,
#      'size': 1,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951168119468750,
#      'mark': 0},
#     'duration': 248792,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 14591005,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17716748288},
#    {'id': 2648887149,
#     'name': '火鸟',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 2511006,
#      'name': '火鸟',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1326816000007,
#      'size': 8,
#      'copyrightId': 0,
#      'status': 1,
#      'picId': 109951163061818990,
#      'mark': 0},
#     'duration': 215240,
#     'copyrightId': 0,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 0,
#     'rUrl': None,
#     'mark': 0},
#    {'id': 316405,
#     'name': '炼金术',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31348,
#      'name': '囍爱杨千嬅',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1286208000000,
#      'size': 28,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951163447791550,
#      'alia': ['新歌+精选'],
#      'mark': 0},
#     'duration': 250692,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': ['电影《煎酿三宝》主题曲'],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17180139520},
#    {'id': 532711207,
#     'name': '最好的债',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 37391046,
#      'name': '如果大家都拥有海',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1449763200000,
#      'size': 10,
#      'copyrightId': 7002,
#      'status': -1,
#      'picId': 109951168143436820,
#      'mark': 0},
#     'duration': 250055,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': ['My Best Enemy'],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 376305,
#     'fee': 8,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316877,
#     'name': '自由行',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31381,
#      'name': '2004开大',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1074614400000,
#      'size': 7,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951163447780940,
#      'mark': 0},
#     'duration': 240973,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 317149,
#     'name': '一千零一个',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31405,
#      'name': "Miriam's Music Box",
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1037894400000,
#      'size': 12,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163447781330,
#      'mark': 0},
#     'duration': 231735,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 14265476,
#     'fee': 8,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316639,
#     'name': '杨千嬅',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31362,
#      'name': 'Simply Me',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p2.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1170777600000,
#      'size': 48,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163270254510,
#      'alia': ['新曲+精选'],
#      'mark': 0},
#     'duration': 202000,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 14249134,
#     'fee': 8,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 1947537070,
#     'name': '高山低谷 (Live)',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      {'id': 10558,
#       'name': '周笔畅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      {'id': 29802127,
#       'name': '单依纯',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 144992545,
#      'name': '声生不息 第4期',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1652544000000,
#      'size': 8,
#      'copyrightId': 2708778,
#      'status': 1,
#      'picId': 109951167417916510,
#      'mark': 0},
#     'duration': 254090,
#     'copyrightId': 2708778,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17716748288},
#    {'id': 316631,
#     'name': '姊妹',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31362,
#      'name': 'Simply Me',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1170777600000,
#      'size': 48,
#      'copyrightId': 7003,
#      'status': 1,
#      'picId': 109951163270254510,
#      'alia': ['新曲+精选'],
#      'mark': 0},
#     'duration': 268120,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 8,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316423,
#     'name': '小星星',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31348,
#      'name': '囍爱杨千嬅',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1286208000000,
#      'size': 28,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951163447791550,
#      'alia': ['新歌+精选'],
#      'mark': 0},
#     'duration': 226453,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17180139520},
#    {'id': 316580,
#     'name': '命硬',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31356,
#      'name': '千嬅新唱金牌金曲',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1406822400000,
#      'size': 15,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951164084481440,
#      'mark': 0},
#     'duration': 218731,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17180139520},
#    {'id': 532711210,
#     'name': '好不容易遇见爱',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 37391046,
#      'name': '如果大家都拥有海',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1449763200000,
#      'size': 10,
#      'copyrightId': 7002,
#      'status': -1,
#      'picId': 109951168143436820,
#      'mark': 0},
#     'duration': 258973,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': ['Love Finally'],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 8,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 316889,
#     'name': '花好月圆夜(国)',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      {'id': 4895,
#       'name': '任贤齐',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31381,
#      'name': '2004开大',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1074614400000,
#      'size': 7,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951163447780940,
#      'mark': 0},
#     'duration': 148040,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': ['电影《花好月圆》插曲'],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 5570708,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 1360515268,
#     'name': '处处吻',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 78692673,
#      'name': '大男人真女人',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1435766400000,
#      'size': 32,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951164016407140,
#      'mark': 0},
#     'duration': 202000,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 2045048373,
#     'name': '无去无来',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 165067807,
#      'name': '无去无来',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1683475200000,
#      'size': 1,
#      'copyrightId': 7002,
#      'status': 1,
#      'picId': 109951168592768420,
#      'mark': 0},
#     'duration': 279346,
#     'copyrightId': 7002,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 14624169,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17716748288},
#    {'id': 317000,
#     'name': '咬唇',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 31386,
#      'name': "Miriam's Melodies",
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1069862400000,
#      'size': 32,
#      'copyrightId': 5003,
#      'status': 1,
#      'picId': 7836219371362214,
#      'mark': 0},
#     'duration': 205148,
#     'copyrightId': 7003,
#     'status': 0,
#     'alias': ['电影《新札师妹Ⅱ美丽任务》主题曲'],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 58147,
#     'fee': 8,
#     'rUrl': None,
#     'mark': 17179877376},
#    {'id': 27598818,
#     'name': '捞月亮的人',
#     'artists': [{'id': 10204,
#       'name': '杨千嬅',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None}],
#     'album': {'id': 2643300,
#      'name': 'Wonder Miriam',
#      'artist': {'id': 0,
#       'name': '',
#       'picUrl': None,
#       'alias': [],
#       'albumSize': 0,
#       'picId': 0,
#       'fansGroup': None,
#       'img1v1Url': 'https://p1.music.126.net/6y-UleORITEDbvrOLV0Q8A==/5639395138885805.jpg',
#       'img1v1': 0,
#       'trans': None},
#      'publishTime': 1222358400007,
#      'size': 12,
#      'copyrightId': 0,
#      'status': 1,
#      'picId': 109951166890588320,
#      'mark': 0},
#     'duration': 219733,
#     'copyrightId': 1416004,
#     'status': 0,
#     'alias': [],
#     'rtype': 0,
#     'ftype': 0,
#     'mvid': 0,
#     'fee': 1,
#     'rUrl': None,
#     'mark': 17179877376}],
#   'hasMore': True,
#   'songCount': 277},
#  'code': 200}

# %%
#把歌名打印出来
songs = data.get('result').get('songs')

for song in songs:
    print(song.get('name'))
# Out:
# 野孩子
# 稀客
# 少女的祈祷(Live)
# 可惜我是水瓶座
# 处处吻
# 再见二丁目(Live)
# 小城大事
# 无去无来
# 勇
# 最好的债
# 飞女正传
# 捞月亮的人
# 无条件 (Live)
# 高山低谷 (Live)
# 还有事情可庆祝
# 塔罗迷
# 花好月圆夜(国)
# 自由行
# 假如让我说下去
# 一千零一个
# 寒舍
# 偷生
# 火鸟
# 芬梨道上
# 姊妹
# 人情世故
# 小星星
# 好不容易遇见爱
# 烈女
# 每当变幻时
