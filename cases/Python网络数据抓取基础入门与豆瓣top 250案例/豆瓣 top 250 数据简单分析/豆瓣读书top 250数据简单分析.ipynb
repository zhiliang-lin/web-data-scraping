# %%
# !pip install pandas matplotlib
# Out:
# Requirement already satisfied: pandas in e:\program files\anaconda3\lib\site-packages (1.5.3)
# ERROR: Could not find a version that satisfies the requirement nump (from versions: none)
# ERROR: No matching distribution found for nump

# %%
import pandas as pd
import matplotlib.pyplot as plt


plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文字体设置-黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决保存图像是负号'-'显示为方块的问题

# %% [markdown]
# # 读取数据

# %%
df = pd.read_excel("douban_book_250.xlsx")

# %% [markdown]
# # 观察数据

# %%
df.head()
# Out:
#    ranking       book_name                authors  publisher     pub_time  \
# 0        1             红楼梦                [清]曹雪芹著    人民文学出版社     1996-12
# 1        2              活着                     余华      作家出版社    2012-8-1
# 2        3            1984           [英]乔治·奥威尔刘绍铭  北京十月文艺出版社    2010-4-1
# 3        4  三体全集 : 地球往事三部曲                    刘慈欣      重庆出版社      2012-1
# 4        5           哈利·波特  J.K.罗琳(J.K.Rowling)苏农    人民文学出版社   2008-12-1
#
#              desc  score  people_num     price  \
# 0    都云作者痴，谁解其中味？    9.6      413885    59.70元
# 1         生的苦难与伟大    9.4      806552    20.00元
# 2  栗树荫下，我出卖你，你出卖我    9.4      275815     28.00
# 3         地球往事三部曲    9.5      178124   168.00元
# 4      从9¾站台开始的旅程    9.7       99452   498.00元
#
#                                                intro
# 0  《红楼梦》是一部百科全书式的长篇小说。以宝黛爱情悲剧为主线，以四大家族的荣辱兴衰为背景，描绘...
# 1  《活着(新版)》讲述了农村人福贵悲惨的人生遭遇。福贵本是个阔少爷，可他嗜赌如命，终于赌光了家...
# 2  ★ 村上春树以《1Q84》向本书致敬    ★ 著名学者刘绍铭经典译本内地首次出版    ★...
# 3  《地球往事·三体》    文化大革命如火如荼进行的同时，军方探寻外星文明的绝秘计划“红岸工程...
# 4  《哈利 · 波特 (共 7 册)(精)》编著者 J.K. 罗琳。        《哈利 · ...

# %% [markdown]
# # 排序

# %%
df.sort_values("people_num",ascending=False)#降序
# Out:
#                       book_name              authors     publisher  \
# 1                            活着                  余华          作家出版社
# 51                        追风筝的人    [美] 卡勒德·胡赛尼  李继宏        上海人民出版社
# 223                       解忧杂货店       [日] 东野圭吾  李盈春         南海出版公司
# 12                          小王子     [法] 圣埃克苏佩里  马振聘        人民文学出版社
# 61                      嫌疑人X的献身       [日] 东野圭吾  刘子倩         南海出版公司
# ..                          ...                  ...           ...
# 242                           坟                  鲁迅        人民文学出版社
# 226                         会饮篇      [古希腊] 柏拉图  王太庆          商务印书馆
# 237               规训与惩罚 : 监狱的诞生     [法] 米歇尔·福柯  刘北成   生活·读书·新知三联书店
# 249  跨越边界的社区（修订版） : 北京“浙江村”的生活史                  项飙   生活·读书·新知三联书店
# 202                        雕刻时光  [苏] 安德烈·塔可夫斯基  张晓东         南海出版公司
#
#        pub_time                   desc  score  people_num    price
# 1     2012-8-1                 生的苦难与伟大    9.4      807701   20.00元
# 51      2006-5                为你，千千万万遍    8.9      785415   29.00元
# 223     2014-5   现代人内心流失的东西，这家杂货店能帮你找回    8.5      752331   39.50元
# 12      2003-8             献给长成了大人的孩子们    9.1      743614   22.00元
# 61      2008-9             数学好是一种极致的浪漫    8.9      515385    28.00
# ..          ...                    ...    ...         ...      ...
# 242    2006-12                     NaN    9.6       11467   16.00元
# 226     2013-1                     NaN    9.3       11034   12.00元
# 237     2003-1     伴随着惩罚的人性化，自由反而日益丧失了    9.3       10552   21.80元
# 249     2018-3                     NaN    9.5        9032   68.00元
# 202     2016-5                     NaN    9.5        8574   45.00元
#
# [250 rows x 8 columns]

# %%
df.sort_values("score",ascending=False)
# Out:
#                    book_name                    authors     publisher  \
# 169  南京大屠杀 : 第二次世界大战中被遗忘的大浩劫   [美]张纯如（Iris Chang）  谭春霞          中信出版社
# 4                      哈利·波特  J.K.罗琳 (J.K.Rowling)  苏农        人民文学出版社
# 101                毛泽东选集 第一卷                       毛泽东          人民出版社
# 0                        红楼梦                 [清] 曹雪芹 著        人民文学出版社
# 242                        坟                        鲁迅        人民文学出版社
# ..                       ...                        ...           ...
# 187                       情书             [日] 岩井俊二  穆晓芳        天津人民出版社
# 220                     骆驼祥子                        老舍        人民文学出版社
# 233                      金锁记                       张爱玲         哈尔滨出版社
# 231                       目送                       龙应台   生活·读书·新知三联书店
# 223                    解忧杂货店             [日] 东野圭吾  李盈春         南海出版公司
#
#         pub_time                    desc  score  people_num     price
# 169      2015-8                      NaN    9.7       15442    49.00元
# 4     2008-12-1               从9¾站台开始的旅程    9.7       99734   498.00元
# 101      1991-6                      NaN    9.6       26500    40.00元
# 0       1996-12             都云作者痴，谁解其中味？    9.6      414261    59.70元
# 242     2006-12                      NaN    9.6       11467    16.00元
# ..           ...                     ...    ...         ...       ...
# 187      2004-7        一场同名同姓的误会，两段可贵的爱情    8.6      106158    18.00元
# 220    2000-3-1          旧中国老北京贫苦市民的典型命运    8.6      204517     12.00
# 233      2005-6   一个小商人家庭出身的女子曹七巧的心灵变迁历程    8.6       62000     13.5元
# 231     2009-10                      不必追    8.6      210738    39.00元
# 223      2014-5    现代人内心流失的东西，这家杂货店能帮你找回    8.5      752331    39.50元
#
# [250 rows x 8 columns]

# %% [markdown]
# # 数据筛选

# %%
author_list = ["鲁迅","三毛","金庸","王小波"]

filtered_authors_df = df[df['authors'].isin(author_list)]

# %%
filtered_authors_df.head(2) #看前两行
# Out:
#     ranking book_name authors     publisher  pub_time       desc  score  \
# 13       14    撒哈拉的故事      三毛        哈尔滨出版社   2003-8     游荡的自由灵魂    9.2
# 15       16      天龙八部      金庸  生活·读书·新知三联书店   1994-5   有情皆孽，无人不冤    9.2
#
#     people_num    price                                              intro
# 13      167776   15.80元  安徒生是丹麦19世纪著名童话作家，世界文学童话创始人。他生于欧登塞城一个贫苦鞋匠家庭，早年在...
# 15      130360   96.00元  天龙八部乃金笔下的一部长篇小说，与《射雕》，《神雕》等 几部长篇小说一起被称为可读性最高的金...

# %% [markdown]
# # 单变量分析

# %% [markdown]
# ## 类别变量

# %%
df[["publisher"]].value_counts()
# Out:
# publisher
# 人民文学出版社         38
# 上海译文出版社         22
# 生活·读书·新知三联书店    19
# 译林出版社           14
# 南海出版公司          12
#                 ..
# 广西美术出版社          1
# 文汇出版社            1
# 时代文艺出版社          1
# 春风文艺出版社          1
# 陕西人民出版社          1
# Length: 72, dtype: int64

# %%
df[["authors"]].value_counts()
# Out:
# authors
# 鲁迅                    6
# 三毛                    6
# 金庸                    5
# 王小波                   5
# 龙应台                   4
#                      ..
# [美] 艾·弗洛姆  李健鸣        1
# [美] 艾萨克·阿西莫夫  叶李华     1
# [美] 艾萨克·阿西莫夫  崔正男     1
# [美] 贾雷德·戴蒙德  谢延光      1
# （清）沈复                 1
# Length: 202, dtype: int64

# %%
table = filtered_authors_df[["authors"]].value_counts()

# %%
table.plot.pie()
# Out:
# <Axes: >

# %% [markdown]
# ## 数值变量

# %%
df["people_num"].describe()
# Out:
# count       250.000000
# mean      86273.204000
# std      120755.120259
# min        8574.000000
# 25%       24245.250000
# 50%       46869.000000
# 75%       90836.250000
# max      807701.000000
# Name: people_num, dtype: float64

# %%
df["people_num"].plot.hist(bins=10, color='skyblue', edgecolor='black', alpha=0.7)

plt.title('豆瓣读书Top 250 评分人数分布图')
plt.xlabel('评分人数')
plt.ylabel('频次')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # 多变量分析

# %% [markdown]
# ## 分组比较

# %%
df.groupby(by="authors")["score"].mean() # 不同作者书籍的平均评分
# Out:
# authors
# (俄罗斯) 陀思妥耶夫斯基  曾思艺           9.300
# (德)叔本华  韦启昌                  9.200
# J.K.罗琳 (J.K.Rowling)  苏农     9.700
# [以色列] 尤瓦尔·赫拉利  林俊宏           9.100
# [俄] 列夫·托尔斯泰  草婴              9.200
#                              ...
# 鲁迅                           9.350
# 黄元吉                          9.500
# 龙应台                          8.675
# （丹麦）安徒生  叶君健                 9.300
# （清）沈复                        8.700
# Name: score, Length: 202, dtype: float64

# %%
pd.pivot_table(df,index=["publisher"],values=["score","people_num"],aggfunc="mean")
# Out:
#               people_num     score
# publisher
# 1981-8     130422.000000  9.300000
# 万卷出版公司      20500.000000  9.100000
# 上海三联书店     109487.000000  8.850000
# 上海人民出版社    170108.000000  9.000000
# 上海古籍出版社     33725.000000  9.200000
# ...                  ...       ...
# 译林出版社       55064.428571  8.971429
# 辽宁教育出版社     33976.000000  9.200000
# 重庆出版社       97985.500000  9.500000
# 长江文艺出版社     76466.000000  8.800000
# 陕西人民出版社     19821.000000  9.500000
#
# [72 rows x 2 columns]

# %%
filtered_authors_df.groupby(by="authors").score.mean() # 不同作者书籍的平均评分
# Out:
# authors
# 三毛     8.966667
# 王小波    8.940000
# 金庸     9.000000
# 鲁迅     9.350000
# Name: score, dtype: float64

# %%
pd.pivot_table(filtered_authors_df ,index=["authors"],values=["score","people_num"],aggfunc="mean")
# Out:
#            people_num     score
# authors
# 三毛       74035.000000  8.966667
# 王小波      95179.000000  8.940000
# 金庸       87942.400000  9.000000
# 鲁迅       77612.333333  9.350000
